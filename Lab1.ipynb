# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/erconui/cs501r/blob/master/Lab1.ipynb)

# %% [markdown]
# Part 1

# %%
import IPython.display
import PIL.Image
import numpy as np
import matplotlib.pyplot as plt
from random import random, uniform
 
plt.legend
plt.xlabel
plt.ylabel
 
plt.tight_layout

fig, ax = plt.subplots()

for i in range(50):
  x = uniform(.05,.9)
  y = uniform(.05,.9)
  r = random()/30
  c = plt.Circle((x,y), r)
  ax.add_artist(c)
  
# circle1 = plt.Circle((0, 0), 0.2, color='r')
# circle2 = plt.Circle((0.5, 0.5), 0.2, color='blue')
# circle3 = plt.Circle((1, 1), 0.2, color='g', clip_on=False)

# ax.add_artist(circle1)
# ax.add_artist(circle2)
# ax.add_artist(circle3)

# %% [markdown]
# Part 2
#
# ![]( https://raw.githubusercontent.com/erconui/cs501r/master/tensorstuff.png)

# %% [markdown]
#  ![Alt text]()
